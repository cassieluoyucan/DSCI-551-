# %%
import requests 
import json
import pandas as pd
import sys

# %% [markdown]
# file1 = 'country.json'
# file2 = 'city.json'
# file3 = 'countrylanguage.json'
#
# excution_format = python pandas-A.py country.json city.json countrylanguage.json

# %% [markdown]
# df_country = pd.read_json("country.json")  ### read data
# df_city = pd.read_json("city.json")
# df_language = pd.read_json("countrylanguage.json")

# %%
#df_1.head(10)

# %%
#df_2.head(10)

# %%
df_country = pd.read_json("country.json")  ### read data 
df_city = pd.read_json("city.json")
df_language = pd.read_json("countrylanguage.json")
        
print(len(df_country))
# Out:
# 239

# %%
df_country
# Out:
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# 235  YUG    Yugoslavia         Europe            Southern Europe     102173.0
# 236  ZAF  South Africa         Africa            Southern Africa    1221037.0
# 237  ZMB        Zambia         Africa             Eastern Africa     752618.0
# 238  ZWE      Zimbabwe         Africa             Eastern Africa     390757.0
#
# ...

# %%
df_test = df_country[df_country.Continent == 'North America']

# %%
#df_test

# %%
print(len(df_test))
# Out:
# 37

# %%
df_test_1 = df_country.loc[df_country.Continent == 'North America']

# %%
df_test_1
# Out:
#     Code                              Name      Continent           Region  \
# 0    ABW                             Aruba  North America        Caribbean
# 3    AIA                          Anguilla  North America        Caribbean
# 6    ANT              Netherlands Antilles  North America        Caribbean
# 13   ATG               Antigua and Barbuda  North America        Caribbean
# 24   BHS                           Bahamas  North America        Caribbean
# 27   BLZ                            Belize  North America  Central America
# 28   BMU                           Bermuda  North America    North America
# 31   BRB                          Barbados  North America        Caribbean
# 37   CAN                            Canada  North America    North America
# 50   CRI                        Costa Rica  North America  Central America
# 51   CUB                              Cuba  North America        Caribbean
# ...

# %%
df = df_city.merge(df_country[df_country.Continent == 'North America'], 
                   left_on='ID', 
                   right_on="Capital", how='inner')

# %%
df.head()
# Out:
#     ID         Name_x CountryCode        District  Population_x Code  \
# 0   33     Willemstad         ANT        CuraÃ§ao          2345  ANT
# 1   62     The Valley         AIA              Â–           595  AIA
# 2   63  Saint JohnÂ´s         ATG         St John         24000  ATG
# 3  129     Oranjestad         ABW              Â–         29034  ABW
# 4  148         Nassau         BHS  New Providence        172000  BHS
#
#                  Name_y      Continent     Region  SurfaceArea  IndepYear  \
# 0  Netherlands Antilles  North America  Caribbean        800.0          0
# 1              Anguilla  North America  Caribbean         96.0          0
# 2   Antigua and Barbuda  North America  Caribbean        442.0       1981
# 3                 Aruba  North America  Caribbean        193.0          0
# 4               Bahamas  North America  Caribbean      13878.0       1973
#
#    Population_y  LifeExpectancy     GNP  GNPOld             LocalName  \
# ...

# %%
### select countries and captical city name 
ans_df = df[['Name_y','Name_x']]

# %%
ans_df
# Out:
#                               Name_y                    Name_x
# 0               Netherlands Antilles                Willemstad
# 1                           Anguilla                The Valley
# 2                Antigua and Barbuda             Saint JohnÂ´s
# 3                              Aruba                Oranjestad
# 4                            Bahamas                    Nassau
# 5                           Barbados                Bridgetown
# 6                             Belize                  Belmopan
# 7                            Bermuda                  Hamilton
# 8            Virgin Islands, British                 Road Town
# 9                     Cayman Islands               George Town
# 10                        Costa Rica                 San JosÃ©
# 11                          Dominica                    Roseau
# 12                Dominican Republic  Santo Domingo de GuzmÃ¡n
# 13                       El Salvador              San Salvador
# ...

# %%
print(ans_df)
# Out:
#                               Name_y                    Name_x
# 0               Netherlands Antilles                Willemstad
# 1                           Anguilla                The Valley
# 2                Antigua and Barbuda             Saint JohnÂ´s
# 3                              Aruba                Oranjestad
# 4                            Bahamas                    Nassau
# 5                           Barbados                Bridgetown
# 6                             Belize                  Belmopan
# 7                            Bermuda                  Hamilton
# 8            Virgin Islands, British                 Road Town
# 9                     Cayman Islands               George Town
# 10                        Costa Rica                 San JosÃ©
# 11                          Dominica                    Roseau
# 12                Dominican Republic  Santo Domingo de GuzmÃ¡n
# 13                       El Salvador              San Salvador
# ...

# %%
if __name__ == "__main__":
    if (len(sys.argv)!=4):# if user does not pass an input
        print ('Usage python filename csv_file_name')
        sys.exit(1)
        
    try:
        df_country = pd.read_json(sys.argv[1])  ### read data 
        df_city = pd.read_json(sys.argv[2])
        df_language = pd.read_json(sys.argv[3])
        
        ## join two dataframe based on ID and capital
        df = df_city.merge(df_country[df_country.Continent == 'North America'], 
                   left_on='ID', 
                   right_on="Capital", how='inner')
    ### select countries and captical city name
        df_ans = df[['Name_y','Name_x']]
        
        print(df_ans)
        
    
    except ValueError:
        print('error occur')
